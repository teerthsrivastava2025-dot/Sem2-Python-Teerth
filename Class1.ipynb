# %% [markdown]
# <a href="https://colab.research.google.com/github/teerthsrivastava2025-dot/Python-Basica/blob/main/Class1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
population = 1435363626727228
print(population)
# Out:
# 1435363626727228

# %%
unemployment_rate = 74523647869846378292

print(unemployment_rate)
# Out:
# 74523647869846378292

# %%
Years_until_20230= 2030-2025
print(Years_until_20230)
# Out:
# 5

# %%
a=print("Wassup y'all t'is nicki minaj")
# Out:
# Wassup y'all t'is nicki minaj

# %%
type(Years_until_20230)
# Out:
# int

# %%
inflation_rate =5.42
gdp_growth=6.3

print("The inflation rate today is=",inflation_rate)
# Out:
# The inflation rate today is= 5.42

# %%
name = "Teerth"

print(name)
print("his name is", name)
# Out:
# Teerth
# his name is Teerth

# %% [markdown]
# LIST

# %%
foods= ["pizza","burger",'fries', 'coke', 15, 6.5]
print(foods)
type(foods)
# Out:
# ['pizza', 'burger', 'fries', 'coke', 15, 6.5]
# list

# %% [markdown]
# How a list solves problems

# %%
numbers=[346,420,123,25,503,96]

print(numbers)
numbers.append(68)
print(numbers)
numbers.pop()
print(numbers)
numbers.pop(2)
print(numbers)
# Out:
# [346, 420, 123, 25, 503, 96]
# [346, 420, 123, 25, 503, 96, 68]
# [346, 420, 123, 25, 503, 96]
# [346, 420, 25, 503, 96]

# %%
print(sorted(numbers))
# Out:
# [25, 96, 123, 346, 420, 503]

# %% [markdown]
# TUPLE

# %%
number=(1,6,'hi',3.7)
print(number)

type(number)
# Out:
# (1, 6, 'hi', 3.7)
# tuple
